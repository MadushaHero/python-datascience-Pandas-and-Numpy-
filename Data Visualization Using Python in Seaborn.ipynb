# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fmri = sns.load_dataset("fmri")
fmri.head(550)
# Out:
#     subject  timepoint event    region    signal
# 0       s13         18  stim  parietal -0.017552
# 1        s5         14  stim  parietal -0.080883
# 2       s12         18  stim  parietal -0.081033
# 3       s11         18  stim  parietal -0.046134
# 4       s10         18  stim  parietal -0.037970
# ..      ...        ...   ...       ...       ...
# 545      s5          5   cue  parietal  0.028700
# 546      s2          4   cue  parietal  0.048464
# 547      s3          5   cue  parietal  0.088904
# 548      s2          5   cue  parietal  0.007216
# 549      s1          5   cue  parietal  0.215735
#
# [550 rows x 5 columns]

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri)
plt.show()

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=fmri,style="event")
plt.show()

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=fmri,style="event",markers=True)
plt.show()

# %%
import pandas as pd

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.barplot(x="Legendary",y="Attack",data=pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %%
sns.barplot(x="Legendary",y="Attack",hue="Generation",data=pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %%
sns.barplot(x="Legendary",y="Attack",data=pokemon,palette='rocket')
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %%
sns.barplot(x="Legendary",y="Attack",data=pokemon,palette='vlag')
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Attack'>

# %%
import pandas as pd

# %%
iris = pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(x="SepalLengthCm",y="PetalLengthCm",data=iris)

# %%
sns.scatterplot(x="SepalLengthCm",y="PetalLengthCm",data=iris)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x="SepalLengthCm",y="PetalLengthCm",hue="Species",style="Species",data=iris)
plt.show()

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(x="SepalLengthCm",y="PetalLengthCm",hue="PetalLengthCm",data=iris)
plt.show()

# %%
diamonds = pd.read_csv("diamonds.csv")
diamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
sns.distplot(diamonds['price'])
plt.show()
# Out:
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],hist=False)
plt.show()
# Out:
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],color="red")
plt.show()
# Out:
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],color="red",kde=False,)
plt.show()
# Out:
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],color="red",kde=False,bins=10)
plt.show()

# %%
sns.distplot(diamonds['price'],color="orange",vertical=True)
plt.show()
# Out:
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Madusha\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
iris = pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.jointplot(x="SepalLengthCm",y="PetalLengthCm",data=iris,color="olive")

# %%
sns.jointplot(x="SepalLengthCm",y="PetalLengthCm",data=iris,color="olive",kind="reg")

# %%
sns.boxplot(y="tenure",x="Contract",data=churn,order=['Two year','Month-to-month','One year'])
plt.show()

# %%
churn = pd.read_csv("churn.csv")
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.boxplot(y="tenure",x="Churn",data=churn)
plt.show()

# %%
sns.boxplot(y="MonthlyCharges",x="InternetService",data=churn)
plt.show()

# %%
sns.boxplot(y="tenure",x="Contract",data=churn,palette='Set1')
plt.show()

# %%
sns.boxplot(y="tenure",x="Contract",data=churn,linewidth=3)
plt.show()

# %%
sns.boxplot(y="tenure",x="Contract",data=churn,order=['Two year','Month-to-month','One year'])
plt.show()

# %%
sns.boxplot(y="tenure",x="Contract",hue='PaymentMethod',data=churn)
plt.show()
