# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='green')

# %%
plt.plot(x,y,color='green',linewidth=5)

# %%
plt.plot(x,y,color='green',linewidth=5,linestyle='dashdot')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y,'b+--')

# %%
plt.plot(x,y,'--r*')

# %%
plt.plot(x,y,'rd')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#19350B',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#19350B',marker='D',linestyle='',markersize=20)

# %%
plt.plot(x,y,color='green',marker='+',linestyle='',markersize=20)

# %%
plt.plot(x,y,color='green',alpha=1)

# %%
plt.plot(x,y,color='green',alpha=0.2)
